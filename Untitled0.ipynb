# %% [markdown]
# <a href="https://colab.research.google.com/github/Andreyka452/4M_heat_rod/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np              # Массивы (матрицы, векторы, линейная алгебра)
import matplotlib.pyplot as plt # Научная графика
# %matplotlib inline 
    # Говорим jupyter'у, чтобы весь графический вывод был в браузере, а не в отдельном окне
import pandas as pd             # Таблицы и временные ряды (dataframe, series)
import seaborn as sns           # Еще больше красивой графики для визуализации данных
import sklearn                  # Алгоритмы машинного обучения

# %% [markdown]
# ## Описание, визуализация.

# %%
data = pd.read_csv('/content/drive/My Drive/file/vehicles_full.csv')

# %% [markdown]
# Здесь представлен набор данных поддержанных автомобилей.
# Необходимо в зависимости от параметров определить состояние автомобиля. (Excellent, good, like new, fair, new, salvage). В данном наборе данных представлены следующие признаки:
# id, url, vin,  region, region_url, price year, manufacturer, model,  condition,  cylinders,  fuel, odometer, title_status, transmission, vin,  drive,  size, type, paint_color,  image_url,  description,  county, state,  lat,  long.
# Характеристики, которые не влияют на состояние (id), сложно интерпритировь (url, description), дублируются (region_url - region). Также в характеристике модель :14284 уникальных значений и при бинаризации не хватает памяти, но есть характеристика марка – manufacturer, марка и модель на прямую зависят друг от друга. В характеристике марка – 42 уникальных значения, поэтому будем считать, что у каждой марки одинаковое качество сборки для всех моделей и характеристику модель мы тоже исключим для экономии памяти.
# В county нет ни одного заполненного значения, удалим его тоже.
# Итого, следующие характеристики будут исключены:
# id, url,  region_url, description, image_url, model,  county.

# %%
data.shape
# Out:
# (423857, 25)

# %% [markdown]
# Данных очень много : На полных данных метод k-ближайшего соседа выполняется около 3-х часов и сессии в Google Colaboratory не хватает на проведение всех экспериментов. Поэтому будем брать случайную выборку из 10000 автомобилей.

# %%
data = data.sample(10000)

# %%
data.sample(10)
# Out:
#                 id  ...      long
# 208793  7193153689  ... -117.9210
# 55814   7194912637  ...  -71.4276
# 20174   7180494781  ...  -88.1602
# 115858  7195551213  ...       NaN
# 263765  7180237674  ...  -89.0046
# 191209  7185516257  ... -120.1920
# 73230   7196814177  ...       NaN
# 23244   7194432733  ...  -73.8291
# 99876   7194433607  ...  -83.0463
# 19354   7195671996  ...       NaN
#
# [10 rows x 25 columns]

# %%
del data['county']
del data['url']
del data['region_url']
del data['vin']
del data['image_url']
del data['description']
del data['id']
del data['model']

# %%
data_copy = data.copy()

# %%
plt.scatter(data_copy['year'], data_copy['price'])
pass

# %%
plt.scatter(data_copy['year'], data_copy['odometer'])
pass

# %%
plt.scatter(data_copy['odometer'], data_copy['price'])
pass

# %% [markdown]
# ### Борьба с выбросами.

# %%
data_copy['price'].quantile([0.005,.01,.05,.1,.5,.9,.95,.99,.995])
# Out:
# 0.005        0.00
# 0.010        0.00
# 0.050        0.00
# 0.100      331.00
# 0.500     9997.00
# 0.900    30995.40
# 0.950    39924.35
# 0.990    59980.10
# 0.995    70003.98
# Name: price, dtype: float64

# %%
data_copy['year'].quantile([0.005,.01,.05,.1,.5,.9,.95,.99,.995])
# Out:
# 0.005    1953.94
# 0.010    1964.00
# 0.050    1995.00
# 0.100    2002.00
# 0.500    2012.00
# 0.900    2018.00
# 0.950    2019.00
# 0.990    2020.00
# 0.995    2020.00
# Name: year, dtype: float64

# %%
data_copy['odometer'].quantile([0.005,.01,.05,.1,.5,.9,.95,.99,.995])
# Out:
# 0.005         0.00
# 0.010         4.00
# 0.050      9749.20
# 0.100     19725.20
# 0.500     90776.00
# 0.900    180000.00
# 0.950    205000.00
# 0.990    279183.52
# 0.995    315122.48
# Name: odometer, dtype: float64

# %% [markdown]
# Оставим самые популярные по цене, пробегу и году выпуска.

# %%
rows_to_drop = data_copy[
    (data_copy['price'] == 0) |
    (data_copy['price'] < data_copy['price'].quantile(0.005)) | (data_copy['price'] > data_copy['price'].quantile(0.995)) | 
    (data_copy['year'] < data_copy['year'].quantile(0.005)) | (data_copy['year'] > data_copy['year'].quantile(0.995)) |
    (data_copy['odometer']  < data_copy['odometer' ].quantile(0.005)) | (data_copy['odometer']  > data_copy['odometer' ].quantile(0.995))].index
data_itog = data_copy.drop(rows_to_drop)
data_itog.shape
# Out:
# (9023, 17)

# %%
data_itog.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9023 entries, 92140 to 139336
# Data columns (total 17 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   region        9023 non-null   object
#  1   price         9023 non-null   int64
#  2   year          7013 non-null   float64
#  3   manufacturer  6734 non-null   object
#  4   condition     3858 non-null   object
#  5   cylinders     4363 non-null   object
#  6   fuel          6989 non-null   object
#  7   odometer      5856 non-null   float64
#  8   title_status  7005 non-null   object
#  9   transmission  7017 non-null   object
#  10  drive         5008 non-null   object
#  11  size          2175 non-null   object
#  12  type          5163 non-null   object
#  13  paint_color   4832 non-null   object
#  14  state         9023 non-null   object
#  15  lat           7000 non-null   float64
#  16  long          7000 non-null   float64
# dtypes: float64(4), int64(1), object(12)
# memory usage: 5.8 MB

# %%
data_obj = data_itog.select_dtypes(include=['object']).copy()
data_obj.describe()
# Out:
#               region manufacturer  condition  ...  type paint_color state
# count           9023         6734       3858  ...  5163        4832  9023
# unique           385           36          6  ...    13          12    51
# top     north jersey         ford  excellent  ...   SUV       white    ca
# freq              89         1301       1864  ...  1422        1234   959
#
# [4 rows x 12 columns]

# %%
converted_obj = pd.DataFrame()

for col in data_itog.columns:
    if ((col != 'region_url') & (col != 'price') & (col != 'year') & (col != 'odometer') & (col != 'lat') & (col != 'long') & (col != 'vin')):
        num_unique_values = len(data_itog[col].unique())
        num_total_values = len(data_itog[col])
        if num_unique_values / num_total_values < 0.5:
            converted_obj.loc[:,col] = data_itog[col].astype('category')
        else:
            converted_obj.loc[:,col] = data_itog[col]
    else:
        converted_obj.loc[:,col] = data_itog[col]

# %%
converted_obj.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9023 entries, 92140 to 139336
# Data columns (total 17 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   region        9023 non-null   category
#  1   price         9023 non-null   int64
#  2   year          7013 non-null   float64
#  3   manufacturer  6734 non-null   category
#  4   condition     3858 non-null   category
#  5   cylinders     4363 non-null   category
#  6   fuel          6989 non-null   category
#  7   odometer      5856 non-null   float64
#  8   title_status  7005 non-null   category
#  9   transmission  7017 non-null   category
#  10  drive         5008 non-null   category
#  11  size          2175 non-null   category
#  12  type          5163 non-null   category
#  13  paint_color   4832 non-null   category
#  14  state         9023 non-null   category
#  15  lat           7000 non-null   float64
#  16  long          7000 non-null   float64
# dtypes: category(12), float64(4), int64(1)
# memory usage: 588.0 KB

# %%
converted_obj.describe(include=['category'])
# Out:
#               region manufacturer  condition  ...  type paint_color state
# count           9023         6734       3858  ...  5163        4832  9023
# unique           385           36          6  ...    13          12    51
# top     north jersey         ford  excellent  ...   SUV       white    ca
# freq              89         1301       1864  ...  1422        1234   959
#
# [4 rows x 12 columns]

# %%
plt.scatter(converted_obj['year'], converted_obj['price'], alpha=0.01)
pass

# %%
plt.scatter(converted_obj['year'], converted_obj['odometer'], alpha=0.01)
pass

# %%
plt.scatter(converted_obj['odometer'], converted_obj['price'], alpha=0.01)
pass

# %%
sns.distplot(converted_obj['price'], bins=15)
plt.grid()
pass
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
np.random.seed(42)
random_subset = np.random.choice(np.arange(converted_obj.shape[0]), size=1000, replace=False)
plt.scatter(converted_obj.iloc[random_subset]['year'], converted_obj.iloc[random_subset]['price'], alpha=0.4)
plt.xlabel('year')
plt.ylabel('price')
pass

# %%
np.random.seed(42)
random_subset = np.random.choice(np.arange(converted_obj.shape[0]), size=1000, replace=False)
plt.scatter(converted_obj.iloc[random_subset]['year'], converted_obj.iloc[random_subset]['odometer'], alpha=0.4)
plt.xlabel('year')
plt.ylabel('odometer')
pass

# %%
np.random.seed(42)
random_subset = np.random.choice(np.arange(converted_obj.shape[0]), size=1000, replace=False)
plt.scatter(converted_obj.iloc[random_subset]['odometer'], converted_obj.iloc[random_subset]['price'], alpha=0.4)
plt.xlabel('odometer')
plt.ylabel('price')
pass

# %%
plt.figure(figsize = (10, 8))
sns.scatterplot(x='year', y='price', size='size', hue='fuel', data=converted_obj.iloc[random_subset], alpha=0.7)
pass

# %%
sns.pairplot(converted_obj.iloc[random_subset], hue='transmission', diag_kind='hist')
plt.legend()
pass

# %%
sns.jointplot(x='odometer', y='price', alpha=.05, data=converted_obj)
pass

# %%
sns.distplot(converted_obj['odometer'], bins = 20)
pass
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(converted_obj['year'], bins = 15)
pass
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.boxplot(x="condition", y="price", data=converted_obj)
pass

# %%
sns.boxplot(x="condition", y="odometer", data=converted_obj)
pass

# %%
sns.violinplot(x="cylinders", y="price", data=converted_obj)
pass

# %%
corr_mat = converted_obj.corr()
corr_mat
# Out:
#              price      year  odometer       lat      long
# price     1.000000  0.344271 -0.519287  0.027372 -0.122043
# year      0.344271  1.000000 -0.417048  0.007586 -0.067698
# odometer -0.519287 -0.417048  1.000000 -0.001269  0.105542
# lat       0.027372  0.007586 -0.001269  1.000000 -0.225129
# long     -0.122043 -0.067698  0.105542 -0.225129  1.000000

# %%
sns.heatmap(corr_mat, square=True, cmap='coolwarm')
pass

# %% [markdown]
# Самые сильные зависимости — это цена пробег и пробег, причём коррелляция отрицательная, что логично - чем больше пробег и год, тем меньше цена автомобиля.

# %%
corr_mat < -0.4
# Out:
#           price   year  odometer    lat   long
# price     False  False      True  False  False
# year      False  False      True  False  False
# odometer   True   True     False  False  False
# lat       False  False     False  False  False
# long      False  False     False  False  False

# %%
corr_mat.where(np.triu(corr_mat < -0.4, k=1)).stack().sort_values(ascending=False)
# Out:
# year   odometer   -0.417048
# price  odometer   -0.519287
# dtype: float64

# %%
converted_obj['cylinders'].unique()
# Out:
# ['4 cylinders', NaN, '8 cylinders', '6 cylinders', '10 cylinders', '3 cylinders', '5 cylinders', 'other', '12 cylinders']
# Categories (8, object): ['4 cylinders', '8 cylinders', '6 cylinders', '10 cylinders', '3 cylinders',
#                          '5 cylinders', 'other', '12 cylinders']

# %%
converted_obj['paint_color'].unique()
# Out:
# ['grey', NaN, 'white', 'blue', 'silver', ..., 'brown', 'yellow', 'green', 'orange', 'purple']
# Length: 13
# Categories (12, object): ['grey', 'white', 'blue', 'silver', ..., 'yellow', 'green', 'orange',
#                           'purple']

# %%
data['cylinders'].value_counts()
# Out:
# 4 cylinders     1691
# 6 cylinders     1668
# 8 cylinders     1298
# 5 cylinders       37
# 10 cylinders      27
# other             11
# 3 cylinders        8
# 12 cylinders       2
# Name: cylinders, dtype: int64

# %%
sns.countplot(x='paint_color', data=data)
pass

# %% [markdown]
# Белый цвет не выгорает, значит состояние автомобиля не сильно изменяется со временем. Поэтому люди стараются купить белый автомобиль что-бы его покрытие дольше сохраняло товарный вид.

# %%
sns.countplot(x='condition', order=converted_obj['condition'].value_counts().index, hue='fuel', data=data)
pass

# %% [markdown]
# ##Заполнение пропущенных значений

# %%
converted_obj.isna().sum()
# Out:
# region             0
# price              0
# year            2010
# manufacturer    2289
# condition       5165
# cylinders       4660
# fuel            2034
# odometer        3167
# title_status    2018
# transmission    2006
# drive           4015
# size            6848
# type            3860
# paint_color     4191
# state              0
# lat             2023
# long            2023
# dtype: int64

# %%
converted_obj.fillna(data.median(axis = 0), axis=0 , inplace=True)

# %%
converted_obj.isna().sum()
# Out:
# region             0
# price              0
# year               0
# manufacturer    2289
# condition       5165
# cylinders       4660
# fuel            2034
# odometer           0
# title_status    2018
# transmission    2006
# drive           4015
# size            6848
# type            3860
# paint_color     4191
# state              0
# lat                0
# long               0
# dtype: int64

# %%
converted_obj['manufacturer'].fillna(data['manufacturer'].mode().iloc[0], inplace=True)
#converted_obj['model'].fillna(data['model'].mode().iloc[0], inplace=True)
converted_obj['condition'].fillna(data['condition'].mode().iloc[0], inplace=True)
converted_obj['cylinders'].fillna(data['cylinders'].mode().iloc[0], inplace=True)
converted_obj['fuel'].fillna(data['fuel'].mode().iloc[0], inplace=True)
converted_obj['title_status'].fillna(data['title_status'].mode().iloc[0], inplace=True)
converted_obj['transmission'].fillna(data['transmission'].mode().iloc[0], inplace=True)
#converted_obj['vin'].fillna(data['vin'].mode().iloc[0], inplace=True)
converted_obj['drive'].fillna(data['drive'].mode().iloc[0], inplace=True)
converted_obj['size'].fillna(data['size'].mode().iloc[0], inplace=True)
converted_obj['type'].fillna(data['type'].mode().iloc[0], inplace=True)
converted_obj['paint_color'].fillna(data['paint_color'].mode().iloc[0], inplace=True)
#converted_obj['image_url'].fillna(data['image_url'].mode().iloc[0], inplace=True)
#converted_obj['description'].fillna(data['description'].mode().iloc[0], inplace=True)
#data['county'].fillna(data['county'].mode().iloc[0], inplace=True)
converted_obj['state'].fillna(data['state'].mode().iloc[0], inplace=True)

# %% [markdown]
# Пропущенных значений теперь нет.

# %%
converted_obj.isna().sum()
# Out:
# region          0
# price           0
# year            0
# manufacturer    0
# condition       0
# cylinders       0
# fuel            0
# odometer        0
# title_status    0
# transmission    0
# drive           0
# size            0
# type            0
# paint_color     0
# state           0
# lat             0
# long            0
# dtype: int64

# %% [markdown]
# ##Балансировка

# %%
converted_obj['condition'].value_counts()
# Out:
# excellent    7029
# good         1456
# like new      347
# fair          168
# new            18
# salvage         5
# Name: condition, dtype: int64

# %% [markdown]
# Данные не сбалансированные - больше всего отличных автомобилей: 7002. Сделаем другие состояния тоже по 7002 автомобиля.

# %%
condition_col = converted_obj['condition']
condition_col.sample(10)
# Out:
# 220472    excellent
# 100589    excellent
# 419117    excellent
# 384645    excellent
# 402222    excellent
# 52921     excellent
# 284183    excellent
# 174016    excellent
# 388458    excellent
# 118284    excellent
# Name: condition, dtype: category
# Categories (6, object): ['excellent', 'fair', 'good', 'like new', 'new', 'salvage']

# %%
num = 7002
print(num)
converted_obj = pd.concat([ converted_obj[converted_obj['condition']=='excellent'],
                                converted_obj[converted_obj['condition']=='good'].sample(num, replace=True),
                                converted_obj[converted_obj['condition']=='like new'].sample(num, replace=True),
                                converted_obj[converted_obj['condition']=='fair'].sample(num, replace=True),
                                converted_obj[converted_obj['condition']=='new'].sample(num, replace=True),
                                converted_obj[converted_obj['condition']=='salvage'].sample(num, replace=True),
])
converted_obj['condition'].value_counts()
# Out:
# 7002
# excellent    7029
# salvage      7002
# new          7002
# like new     7002
# good         7002
# fair         7002
# Name: condition, dtype: int64

# %% [markdown]
# сохраняем в отдельную колонку результат состояния.

# %%
condition_ = converted_obj['condition']
converted_obj = converted_obj.drop("condition", axis = 1)

# %%
#Building_dummies = pd.get_dummies(condition_[0])
#condition_ = pd.concat((condition_, Building_dummies), axis=1)
#condition_ = condition_.drop(['condition'], axis=1)

# %% [markdown]
# ##Бинаризация.

# %%
Building_dummies = pd.get_dummies(converted_obj['manufacturer'])
converted_obj = pd.concat((converted_obj, Building_dummies), axis=1)
converted_obj = converted_obj.drop(['manufacturer'], axis=1)

# %%
#Building_dummies = pd.get_dummies(converted_obj['model'])
#converted_obj = pd.concat((converted_obj, Building_dummies), axis=1)
#converted_obj = converted_obj.drop(['model'], axis=1)
#не хватает памяти (

# %%
Building_dummies = pd.get_dummies(converted_obj['cylinders'])
converted_obj = pd.concat((converted_obj, Building_dummies), axis=1)
converted_obj = converted_obj.drop(['cylinders'], axis=1)

# %%
Building_dummies = pd.get_dummies(converted_obj['fuel'])
converted_obj = pd.concat((converted_obj, Building_dummies), axis=1)
converted_obj = converted_obj.drop(['fuel'], axis=1)

# %%
Building_dummies = pd.get_dummies(converted_obj['title_status'])
converted_obj = pd.concat((converted_obj, Building_dummies), axis=1)
converted_obj = converted_obj.drop(['title_status'], axis=1)

# %%
Building_dummies = pd.get_dummies(converted_obj['transmission'])
converted_obj = pd.concat((converted_obj, Building_dummies), axis=1)
converted_obj = converted_obj.drop(['transmission'], axis=1)

# %%
Building_dummies = pd.get_dummies(converted_obj['drive'])
converted_obj = pd.concat((converted_obj, Building_dummies), axis=1)
converted_obj = converted_obj.drop(['drive'], axis=1)

# %%
Building_dummies = pd.get_dummies(converted_obj['size'])
converted_obj = pd.concat((converted_obj, Building_dummies), axis=1)
converted_obj = converted_obj.drop(['size'], axis=1)

# %%
Building_dummies = pd.get_dummies(converted_obj['type'])
converted_obj = pd.concat((converted_obj, Building_dummies), axis=1)
converted_obj = converted_obj.drop(['type'], axis=1)

# %%
Building_dummies = pd.get_dummies(converted_obj['paint_color'])
converted_obj = pd.concat((converted_obj, Building_dummies), axis=1)
converted_obj = converted_obj.drop(['paint_color'], axis=1)

# %%
Building_dummies = pd.get_dummies(converted_obj['state'])
converted_obj = pd.concat((converted_obj, Building_dummies), axis=1)
converted_obj = converted_obj.drop(['state'], axis=1)

# %%
Building_dummies = pd.get_dummies(converted_obj['region'])
converted_obj = pd.concat((converted_obj, Building_dummies), axis=1)
converted_obj = converted_obj.drop(['region'], axis=1)

# %% [markdown]
# ##Нормализация количественных признаков
#
# Перед применением алгоритмов машинного обучения количественные признаки полезно нормализовать.
#
# Наиболее часто используют один из двух следующих способов:
# - *приведение к отрезку $[0,1]$* - это линейное преобразование, приводящее все значения к заданному отрезку;
# - *стандартизация* - линейное преобразование, приводящее все значения к нулевому среднему и единичному стандартному отклонению.
#
# Выполним стандартизацию всех признаков:

# %%
converted_obj.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 42039 entries, 92140 to 344976
# Columns: 531 entries, price to zanesville / cambridge
# dtypes: float64(4), int64(1), uint8(526)
# memory usage: 23.0 MB

# %%
data_stand = (converted_obj - converted_obj.mean(axis = 0))/converted_obj.std(axis = 0)

# %%
data_stand.describe()
# Out:
#               price          year  ...          yuma  zanesville / cambridge
# count  4.203900e+04  4.203900e+04  ...  4.203900e+04            4.203900e+04
# mean  -9.739734e-15 -1.126329e-14  ... -4.374508e-15            3.996850e-16
# std    1.000000e+00  1.000000e+00  ...  1.000000e+00            1.000000e+00
# min   -9.330196e-01 -4.891852e+00  ... -1.758764e-02           -2.126393e-02
# 25%   -6.880632e-01 -4.178983e-01  ... -1.758764e-02           -2.126393e-02
# 50%   -4.018723e-01  2.212379e-01  ... -1.758764e-02           -2.126393e-02
# 75%    3.950938e-01  6.777637e-01  ... -1.758764e-02           -2.126393e-02
# max    3.967370e+00  1.134290e+00  ...  5.685677e+01            4.702687e+01
#
# [8 rows x 531 columns]

# %% [markdown]
# ## 7. Отбор признаков

# %% [markdown]
# проверяем на несбалансированность

# %%
condition_.value_counts()
# Out:
# excellent    7029
# salvage      7002
# new          7002
# like new     7002
# good         7002
# fair         7002
# Name: condition, dtype: int64

# %%
X = data_stand
y = condition_
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 42)

N_train, _ = X_train.shape 
N_test,  _ = X_test.shape 

print(N_train, N_test)
# Out:
# 29427 12612

# %% [markdown]
# Посмотрим на случаи, когда количество соседей 10-1

# %%
from sklearn.neighbors import KNeighborsClassifier
for i in range(10,0,-1):
    knn = KNeighborsClassifier(n_neighbors = i)
    knn.fit(X_train, y_train)

    y_train_predict = knn.predict(X_train)
    err_train = np.mean(y_train != y_train_predict)
    print(i, err_train)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-71-61c81e5140fd> in <module>()
#       2 for i in range(10,0,-1):
#       3     knn = KNeighborsClassifier(n_neighbors = i)
# ----> 4     knn.fit(X_train, y_train)
#       5
#       6     y_train_predict = knn.predict(X_train)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/neighbors/_base.py in fit(self, X, y)
#    1149             self._y = self._y.ravel()
#    1150
# -> 1151         return self._fit(X)
#    1152
#    1153
#
# /usr/local/lib/python3.6/dist-packages/sklearn/neighbors/_base.py in _fit(self, X)
#     455             self._tree = KDTree(X, self.leaf_size,
#     456                                 metric=self.effective_metric_,
# --> 457                                 **self.effective_metric_params_)
#     458         elif self._fit_method == 'brute':
#     459             self._tree = None
#
# KeyboardInterrupt:

# %% [markdown]
# Проверка на тестовой выборке

# %%
for i in range(10,0,-1):
    knn = KNeighborsClassifier(n_neighbors = i)
    knn.fit(X_test, y_test)

    y_test_predict = knn.predict(X_test)
    err_test = np.mean(y_test != y_test_predict)
    print(i, err_test)
# Out:
# 10 0.16550301491589972
# 9 0.1461440812440495
# 8 0.1376547127895906
# 7 0.11900983814662013
# 6 0.10647413519517614
# 5 0.0865598222786417
# 4 0.07092986353538559
# 3 0.04863535385591876
# 2 0.02245318946366233
# 1 0.0

# %%
dataDict = {'train':{'data':(X_train, y_train), 'error':[]}, 'test':{'data':(X_test, y_test), 'error':[]}}
for k in range(20,0,-1):
    for key in dataDict:
        X = dataDict[key]['data'][0]
        y = dataDict[key]['data'][1]
        knn = KNeighborsClassifier(n_neighbors = k)
        knn.fit(X, y)
        y_predict = knn.predict(X)
        dataDict[key]['error'].append(np.mean(y != y_predict))
plt.plot(range(20,0,-1), dataDict['train']['error'], '-ob', label="Train error")
plt.plot(range(20,0,-1), dataDict['test']['error'], '-or', label="Test error")
plt.gca().invert_xaxis()
plt.legend()
plt.show()

# %% [markdown]
# Оптимальным количеством будет 2 соседа.

# %%
knn = KNeighborsClassifier(n_neighbors = 2)
knn.fit(X_test, y_test)
y_test_predict = knn.predict(X_test)
err_train = np.mean(y_test != y_test_predict)
print(err_train)
from sklearn.metrics import confusion_matrix
print(confusion_matrix(y_test, y_test_predict))
# Out:
# 0.02245318946366233
# [[2180    0    0    0    0    0]
#  [   0 2116    0    0    0    0]
#  [ 262   10 1820    0    0    0]
#  [   5    0    6 2046    0    0]
#  [   0    0    0    0 2093    0]
#  [   0    0    0    0    0 2066]]

# %% [markdown]
# ##8. Применение PCA

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
X_pca = pca.fit_transform(data_stand)
print("Главные компоненты (по строкам):")
print(pca.components_)
print("Дисперсии по главным компонентам,Cобственные значения вдоль каждой компоненты:")
print(pca.explained_variance_)
print("Среднеквадратические отклонения:")
print(np.sqrt(pca.explained_variance_))
print("Соответствующие сингулярные значения:")
print(pca.singular_values_)
# Out:
# Главные компоненты (по строкам):
# [[-0.06148009 -0.17539838  0.11243091 ... -0.003454    0.00314455
#   -0.00356505]
#  [-0.15442575 -0.2241906   0.01305113 ... -0.00393315 -0.00380528
#   -0.00119808]]
# Дисперсии по главным компонентам,Cобственные значения вдоль каждой компоненты:
# [6.11956361 5.41781337]
# Среднеквадратические отклонения:
# [2.47377517 2.32761968]
# Соответствующие сингулярные значения:
# [507.20234113 477.23583087]

# %%
y = condition_
plt.figure(figsize=(10,10))
for i in range(len(X_pca)):
    plt.scatter(X_pca[i, 0], X_pca[i, 1], c= 'red' if y[i] == 0 else 'blue')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._maybe_get_bool_indexer()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine._unpack_bool_indexer()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-72-7dc669f81cc4> in <module>()
#       2 plt.figure(figsize=(10,10))
#       3 for i in range(len(X_pca)):
# ----> 4     plt.scatter(X_pca[i, 0], X_pca[i, 1], c= 'red' if y[i] == 0 else 'blue')
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/series.py in __getitem__(self, key)
#     880
#     881         elif key_is_scalar:
# --> 882             return self._get_value(key)
#     883
#     884         if is_hashable(key):
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/series.py in _get_value(self, label, takeable)
#     988
#     989         # Similar to Index.get_value, but we do not fall back to positional
# --> 990         loc = self.index.get_loc(label)
#     991         return self.index._get_values_for_loc(self, loc, label)
#     992
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
# -> 2900                 raise KeyError(key) from err
#    2901
#    2902         if tolerance is not None:
#
# KeyError: 0

# %%
pca = PCA(n_components=2)
X_pca = pca.fit_transform(data_stand)
X = X_pca
y = condition_
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 42)

N_train, _ = X_train.shape 
N_test,  _ = X_test.shape 

print(N_train, N_test)
# Out:
# 29427 12612

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors = 3)
knn.fit(X_train, y_train)
knn.fit(X_test, y_test)
y_train_predict = knn.predict(X_train)
y_test_predict = knn.predict(X_test)
err_train = np.mean(y_train != y_train_predict)
err_test = np.mean(y_test != y_test_predict)

print(err_train, err_test)
# Out:
# 0.12733204200224285 0.06612749762131304

# %%
from sklearn.model_selection import train_test_split
err_train_list = []
err_test_list = []
for n_comp in range(2, 10):
    pca = PCA(n_components=n_comp)
    X_pca = pca.fit_transform(data_stand)
    X_train, X_test, y_train, y_test = train_test_split(X_pca, y, test_size = 0.3, random_state = 42)
    knn = KNeighborsClassifier(n_neighbors = 3)
    knn.fit(X_train, y_train)
    knn.fit(X_test, y_test)
    y_train_predict = knn.predict(X_train)
    y_test_predict = knn.predict(X_test)
    err_train = np.mean(y_train != y_train_predict)
    err_test = np.mean(y_test != y_test_predict)
    
    err_train_list.append(err_train)
    err_test_list.append(err_test)
    
plt.plot(range(2, 10), err_train_list, label="Train error")
plt.plot(range(2, 10), err_test_list, label="Test error")
plt.xlabel('n')
plt.ylabel('error')
plt.legend()
plt.show()
print(min(err_train_list), 2 + err_train_list.index(min(err_train_list)))
print(min(err_test_list), 2 + err_test_list.index(min(err_test_list)))
# Out:
# 0.10432595915315866 9
# 0.052251823660006344 9

# %% [markdown]
# ## 7. Применение LDA

# %%
from sklearn import discriminant_analysis
lda_model = discriminant_analysis.LinearDiscriminantAnalysis()
X = data_stand
y = condition_
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 42)  
    
N_train, _ = X_train.shape 
N_test,  _ = X_test.shape 
print(N_train, N_test)


lda_model.fit(X_train, y_train)
y_pred = lda_model.predict(X_train)
y_test_pred = lda_model.predict(X_test)
print (np.mean(y_train != y_pred))
print (np.mean(y_test != y_test_pred))
# Out:
# 29416 12608
# 0.8330160456894207
# 0.8342322335025381

# %%
from sklearn import neighbors
err_train = []
err_test = []
k_range = range(40, 50)
for k in k_range:
    knn_model = neighbors.KNeighborsClassifier(n_neighbors = k)
    knn_model.fit(X_train, y_train)
    knn_model.fit(X_test, y_test)
    y_pred      = knn_model.predict(X_train)
    y_test_pred = knn_model.predict(X_test)
    err_train.append(np.mean(y_train != y_pred))
    err_test.append(np.mean(y_test != y_test_pred))

# %%
plt.plot(k_range, err_train, 'r')
plt.plot(k_range, err_test, 'b')

# %%
print (err_train[3], err_test[3])
# Out:
# 0.38207098177862386 0.359375
